# %% [markdown]
# Authors: Dennis Kolomiyets 20250762,
#          Oussoubi Niakate 20242905

# %% [markdown]
# # Drive Link

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/CS4168PROJECTGROUP12

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Dataset

# %% [markdown]
# The code below is used to fetch Data from the CSV file

# %%
df = pd.read_csv('./steel_industry_data_excerpt.csv')

# %% [markdown]
# # Head

# %%
df.head()
# Out:
#                   date  Usage_kWh  Lagging_Current_Reactive.Power_kVarh  \
# 0  2018-01-01 02:30:00       3.78                                  4.72
# 1  2018-01-01 04:15:00       3.28                                  3.82
# 2  2018-01-01 05:45:00       3.28                                  3.49
# 3  2018-01-01 10:00:00       3.64                                  0.00
# 4  2018-01-01 10:30:00       3.71                                  0.00
#
#    Leading_Current_Reactive_Power_kVarh  CO2(tCO2)  \
# 0                                  0.00        0.0
# 1                                  0.00        0.0
# 2                                  0.00        0.0
# 3                                 16.88        0.0
# 4                                 18.00        0.0
#
#    Lagging_Current_Power_Factor  Leading_Current_Power_Factor    NSM  \
# 0                         62.51                        100.00   9000
# 1                         65.14                        100.00  15300
# ...

# %% [markdown]
# The first 5 rows of the table

# %% [markdown]
# # Tail

# %%
df.tail()
# Out:
#                      date  Usage_kWh  Lagging_Current_Reactive.Power_kVarh  \
# 2185  2018-12-31 06:45:00       3.02                                  2.12
# 2186  2018-12-31 09:45:00       3.17                                  0.00
# 2187  2018-12-31 13:45:00       3.31                                  0.00
# 2188  2018-12-31 20:00:00       4.14                                  0.00
# 2189  2018-12-31 22:45:00       3.82                                  4.54
#
#       Leading_Current_Reactive_Power_kVarh  CO2(tCO2)  \
# 2185                                  0.11        0.0
# 2186                                 14.65        0.0
# 2187                                 13.68        0.0
# 2188                                 20.09        0.0
# 2189                                  0.00        0.0
#
#       Lagging_Current_Power_Factor  Leading_Current_Power_Factor    NSM  \
# 2185                         81.85                         99.93  24300
# ...

# %% [markdown]
# 5 last rows of the table

# %%
df.describe()
# Out:
#          Usage_kWh  Lagging_Current_Reactive.Power_kVarh  \
# count  2190.000000                           2190.000000
# mean     28.438712                             13.658685
# std      34.055560                             16.818180
# min       2.480000                              0.000000
# 25%       3.240000                              2.240000
# 50%       4.640000                              5.040000
# 75%      52.780000                             24.480000
# max     145.300000                             90.680000
#
#        Leading_Current_Reactive_Power_kVarh    CO2(tCO2)  \
# count                           2190.000000  2190.000000
# mean                               3.959279     0.012027
# std                                7.512796     0.016445
# min                                0.000000     0.000000
# 25%                                0.000000     0.000000
# 50%                                0.000000     0.000000
# ...

# %% [markdown]
# The table above shows a summary of the dataset i.e. numerical values from the dataset.

# %%
#Checking for missing values
df.isna().sum()
# Out:
# date                                    0
# Usage_kWh                               0
# Lagging_Current_Reactive.Power_kVarh    0
# Leading_Current_Reactive_Power_kVarh    0
# CO2(tCO2)                               0
# Lagging_Current_Power_Factor            0
# Leading_Current_Power_Factor            0
# NSM                                     0
# WeekStatus                              0
# Day_of_week                             0
# dtype: int64

# %% [markdown]
# According to the table shown above, there are 0 missing values in the dataset which is great news.

# %%
#Dimensions of the csv file
df.shape
# Out:
# (2190, 10)

# %% [markdown]
# # Heatmap

# %%
sns.heatmap(df.corr());
# Out:
# <ipython-input-20-f044f2f5ad42>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr());

# %% [markdown]
# The heat map suggests correlation greater than 0.25 between CO2(tCO2) emmissions and the attributes Usage_kWh, Lagging_Current_Reactive.Power_kVarh and both Current power factors are the same so i will refer to them as power factors.

# %% [markdown]
# # Pairplot

# %%
df['WeekStatus'].value_counts()
# Out:
# Weekday    1586
# Weekend     604
# Name: WeekStatus, dtype: int64

# %%
# note that by applying the method dropna() we drop all rows with missing values
sns.pairplot(data=df[['CO2(tCO2)','Usage_kWh','Lagging_Current_Reactive.Power_kVarh','Lagging_Current_Power_Factor']].dropna())
plt.show()

# %% [markdown]
# # Categorical

# %%
df['Day_of_week'].value_counts()
# Out:
# Friday       333
# Tuesday      327
# Monday       315
# Thursday     314
# Sunday       304
# Saturday     300
# Wednesday    297
# Name: Day_of_week, dtype: int64

# %% [markdown]
# # CO2 Histogram

# %%
df['CO2(tCO2)'].hist(bins=50)
plt.xlabel('CO2 Emissions')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # CO2 Boxplot

# %%
df.boxplot('CO2(tCO2)')
# Out:
# <Axes: >

# %% [markdown]
# # KWh Usage Poxplot

# %%
df.boxplot('Usage_kWh')
# Out:
# <Axes: >

# %% [markdown]
# More outliers spotted in Usage_kWh vs CO2

# %% [markdown]
# # Scatterplot

# %%
df.plot.scatter(x='CO2(tCO2)', y='Usage_kWh')
plt.show()

# %% [markdown]
# This plot shows the amount of CO2 emitted with respect to Usage in KkWh

# %% [markdown]
# # Correlation Histogram

# %% [markdown]
# We will now be exploring the correlation between usage and lagging current reactive power

# %%
df['Usage_kWh'].hist(bins=50)
plt.xlabel('Usage in kWh')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Usage v LCR Scatter

# %%
df.plot.scatter(x='Lagging_Current_Reactive.Power_kVarh', y='Usage_kWh')
plt.show()

# %% [markdown]
# #Conclusion
# Based on the graphs, it's safe to say that kWh usage under is dominant, and the higher the kWh usage, the higher the Lagging Current Reactive Power.
